# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
linear = nn.Linear(3, 2)
linear.weight
# Out:
# Parameter containing:
# tensor([[ 0.3509, -0.0262, -0.2731],
#         [-0.5185,  0.3100, -0.2712]], requires_grad=True)

# %%
nn.init.uniform_(linear.weight)
linear.weight.data
# Out:
# tensor([[0.3380, 0.5359, 0.9584],
#         [0.2422, 0.0284, 0.6006]])
